# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavel-Surkov/My_First_Test_Repo/blob/main/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

# %%
url = "https://ru.wikipedia.org/wiki/%D0%A2%D0%B5%D0%BF%D0%BB%D0%BE%D0%B2%D0%B0%D1%8F_%D1%8D%D0%BD%D0%B5%D1%80%D0%B3%D0%B5%D1%82%D0%B8%D0%BA%D0%B0_%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8"
id_table = 0
df_power = pd.read_html(url, header = 0, index_col = 0)[id_table]
df_power
# Out:
#             Название ТЭС  ...                 Регион
# №                         ...
# 1      Сургутская ГРЭС-2  ...    Ханты-Мансийский АО
# 2        Рефтинская ГРЭС  ...   Свердловская область
# 3       Костромская ГРЭС  ...    Костромская область
# 4          Пермская ГРЭС  ...          Пермский край
# 5      Сургутская ГРЭС-1  ...    Ханты-Мансийский АО
# 6         Рязанская ГРЭС  ...      Рязанская область
# 7         Киришская ГРЭС  ...  Ленинградская область
# 8       Конаковская ГРЭС  ...       Тверская область
# 9       Ириклинская ГРЭС  ...   Оренбургская область
# 10   Ставропольская ГРЭС  ...    Ставропольский край
# 11      Берёзовская ГРЭС  ...      Красноярский край
# 12   Новочеркасская ГРЭС  ...     Ростовская область
# 13         Заинская ГРЭС  ...              Татарстан
# 14  Нижневартовская ГРЭС  ...    Ханты-Мансийский АО
#
# [14 rows x 6 columns]

# %%
#4.1
df_power_3 = df_power.sort_values(['Установленная мощность, МВт'])
df_power_3
# Out:
#             Название ТЭС  ...                 Регион
# №                         ...
# 14  Нижневартовская ГРЭС  ...    Ханты-Мансийский АО
# 12   Новочеркасская ГРЭС  ...     Ростовская область
# 11      Берёзовская ГРЭС  ...      Красноярский край
# 10   Ставропольская ГРЭС  ...    Ставропольский край
# 9       Ириклинская ГРЭС  ...   Оренбургская область
# 8       Конаковская ГРЭС  ...       Тверская область
# 7         Киришская ГРЭС  ...  Ленинградская область
# 6         Рязанская ГРЭС  ...      Рязанская область
# 5      Сургутская ГРЭС-1  ...    Ханты-Мансийский АО
# 4          Пермская ГРЭС  ...          Пермский край
# 3       Костромская ГРЭС  ...    Костромская область
# 2        Рефтинская ГРЭС  ...   Свердловская область
# 13         Заинская ГРЭС  ...              Татарстан
# 1      Сургутская ГРЭС-2  ...    Ханты-Мансийский АО
#
# [14 rows x 6 columns]

# %%
#4.2
df_power_2  = df_power.copy()

df_power_2['выработка за сутки'] = df_power_2['Установленная мощность, МВт'] * 24

df_power_2['природный газ'] = np.where(df_power_2['топливо'].str.find('природный газ') >= 0, '+', '-')

df_power_2
# Out:
#             Название ТЭС  ...  природный газ
# №                         ...
# 1      Сургутская ГРЭС-2  ...              +
# 2        Рефтинская ГРЭС  ...              -
# 3       Костромская ГРЭС  ...              +
# 4          Пермская ГРЭС  ...              +
# 5      Сургутская ГРЭС-1  ...              +
# 6         Рязанская ГРЭС  ...              +
# 7         Киришская ГРЭС  ...              +
# 8       Конаковская ГРЭС  ...              +
# 9       Ириклинская ГРЭС  ...              +
# 10   Ставропольская ГРЭС  ...              +
# 11      Берёзовская ГРЭС  ...              -
# 12   Новочеркасская ГРЭС  ...              +
# 13         Заинская ГРЭС  ...              +
# 14  Нижневартовская ГРЭС  ...              -
#
# [14 rows x 8 columns]

# %%
#4.3
df_power_43 = df_power.copy()
df_power_43 = (df_power[(df_power['Установленная мощность, МВт']	> 3300.) & (df_power['топливо'] == 'природный газ')])
df_power_43
# Out:
#         Название ТЭС  ...               Регион
# №                     ...
# 3   Костромская ГРЭС  ...  Костромская область
# 4      Пермская ГРЭС  ...        Пермский край
# 13     Заинская ГРЭС  ...            Татарстан
#
# [3 rows x 6 columns]

# %%
#4.4
df_power_44 = df_power.copy()
print('данные из всех строк кроме трех последних и из столбцов с первого по третий включительно')
df_power_44 =(df_power_44.iloc[: -3, 0: 3])
df_power_44
# Out:
# данные из всех строк кроме трех последних и из столбцов с первого по третий включительно
#            Название ТЭС  ...                                     топливо
# №                        ...
# 1     Сургутская ГРЭС-2  ...        попутный нефтяной газ, природный газ
# 2       Рефтинская ГРЭС  ...                              каменный уголь
# 3      Костромская ГРЭС  ...                               природный газ
# 4         Пермская ГРЭС  ...                               природный газ
# 5     Сургутская ГРЭС-1  ...        попутный нефтяной газ, природный газ
# 6        Рязанская ГРЭС  ...  бурый уголь, каменный уголь, природный газ
# 7        Киришская ГРЭС  ...                               природный газ
# 8      Конаковская ГРЭС  ...                               природный газ
# 9      Ириклинская ГРЭС  ...                               природный газ
# 10  Ставропольская ГРЭС  ...                               природный газ
# ...

# %%
#4.5
print(df_power_2.groupby(['топливо'])['Регион'].sum())
print()
print(df_power_2.groupby(['природный газ'])['Установленная мощность, МВт'].sum())
# Out:
# топливо
# бурый уголь                                                                   Красноярский край
# бурый уголь, каменный уголь, природный газ                                    Рязанская область
# каменный уголь                                                             Свердловская область
# каменный уголь, природный газ                                                Ростовская область
# попутный нефтяной газ                                                       Ханты-Мансийский АО
# попутный нефтяной газ, природный газ                     Ханты-Мансийский АОХанты-Мансийский АО
# природный газ                                 Костромская областьПермский крайЛенинградская ...
# Name: Регион, dtype: object
#
# природный газ
# +    104272
# -      8231
# Name: Установленная мощность, МВт, dtype: int64

# %%
#4.6
df_power_2.groupby(['природный газ'])['Установленная мощность, МВт'].sum().plot(kind = 'barh')

# %%
#4.7
df_power_2.groupby(['природный газ'])['Установленная мощность, МВт'].sum().plot(kind = 'pie')

# %%
#4.8
output_notebook()

p = figure(plot_width = 50000, plot_height = 50000)

# Список цветов по количеству лет.
colors = ['magenta', 'red', 'yellow', 'green', 'cyan', 'blue', 'black', 'red', 'yellow', 'green', 'cyan', 'blue', 'black', 'magenta']

m = df_power['Установленная мощность, МВт'].iloc[0:]
names = df_power['Название ТЭС'].iloc[0:]

p = figure(plot_width=300, plot_height=300)

#p.hbar(y=[m], height=1000, left=0, color="#CAB2D6")

#for i in range(1, 14):
#  print(m[i])
p.hbar(y=np.arange(len(m.values)) + 1, height=0.5, left=0, right=m.values, color="#CAB2D6")

show(p)
# Out:
#   <div class="bk-root" id="3f2f475e-71f0-462e-bb7e-20134d6840eb" data-root-id="56875"></div>

# %%
print(m.values)
# Out:
# [56571  3800  3600  3363  3333  3130  2595  2520  2430  2423  2400  2258
#  22049  2031]
